# %%
import numpy as np
import pandas as pd

# %%
a = pd.read_csv('2MMR0To5000.csv')
b = pd.read_csv('2MMR5000To10000.csv')
c = pd.read_csv('2MMR10000To15000.csv')
d = pd.read_csv('2MMR15000To20000.csv')

# %%
DL = []
DL.append(pd.read_csv('2MMR0To5000.csv'))
DL.append(pd.read_csv('2MMR5000To10000.csv'))
DL.append(pd.read_csv('2MMR10000To15000.csv'))
DL.append(pd.read_csv('2MMR15000To20000.csv'))
DL.append(pd.read_csv('2MMR20000To25000.csv'))
DL.append(pd.read_csv('2MMR25000To30000.csv'))
DL.append(pd.read_csv('2MMR30000To35000.csv'))
DL.append(pd.read_csv('2MMR35000To40000.csv'))
DL.append(pd.read_csv('2MMR40000To45000.csv'))
DL.append(pd.read_csv('2MMR45000To50000.csv'))

# %%
DL = []
for x in range(0,130000,5000):
    DL.append(pd.read_csv('2MMR'+str(x)+'To'+str(x+5000)+'.csv'))
DL.append(pd.read_csv('2MMR135000To138543.csv'))

# %%
new = pd.concat(DL)

# %%
new = pd.concat([a,b])

# %%
new
# Out:
#        index  EMcrossnear  EMfracstdnear  EPstdnear  MMRstrengthnear  \
# 0          0     0.221502       0.017511   0.002935         0.010371
# 1          1     0.190647       0.073477   0.011405         0.013957
# 2          2     0.125660       0.034270   0.001506         0.088234
# 3          3     0.216684       0.008561   0.002451         0.000000
# 4          4     0.024455            NaN        NaN              NaN
# ...      ...          ...            ...        ...              ...
# 3538  138538     0.082222       0.049940   0.016289         0.024447
# 3539  138539     0.251338       0.016063   0.002925         0.000000
# 3540  138540     0.131799       0.027892   0.001453         0.032653
# 3541  138541     0.209454       0.090838   0.010214         0.037776
# 3542  138542     0.182523            NaN        NaN              NaN
#
#       twoMMRstrengthnear  EMcrossfar  EMfracstdfar  EPstdfar  MMRstrengthfar  \
# ...

# %%
new.to_csv('fullFeature2MMRs.csv')
