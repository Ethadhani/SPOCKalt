# %%
import numpy as np
import pandas as pd

# %%
DL = []
for x in range(0,130000,5000):
    DL.append(pd.read_csv('2MMR'+str(x)+'To'+str(x+5000)+'Outer.csv'))
DL.append(pd.read_csv('2MMR135000To138543Outer.csv'))

# %%
new = pd.concat(DL)

# %%
command = ''
for x in range(1,29,1):
    command = command + f'python {x}.py & '
command = command+'wait'

# %%
command
# Out:
# 'python 1.py & python 2.py & python 3.py & python 4.py & python 5.py & python 6.py & python 7.py & python 8.py & python 9.py & python 10.py & python 11.py & python 12.py & python 13.py & python 14.py & python 15.py & python 16.py & python 17.py & python 18.py & python 19.py & python 20.py & python 21.py & python 22.py & python 23.py & python 24.py & python 25.py & python 26.py & python 27.py & python 28.py & wait'

# %%
new
# Out:
#        index  EMcrossnear  EMfracstdnear  EPstdnear  MMRstrengthnear  \
# 0          0     0.221502       0.017511   0.002935         0.104761
# 1          1     0.190647       0.073477   0.011405         0.033206
# 2          2     0.125660       0.034270   0.001506         0.334176
# 3          3     0.216684       0.008561   0.002451         0.012940
# 4          4     0.024455            NaN        NaN              NaN
# ...      ...          ...            ...        ...              ...
# 3538  138538     0.082222       0.049940   0.016289         0.608276
# 3539  138539     0.251338       0.016063   0.002925         0.252494
# 3540  138540     0.131799       0.027892   0.001453         0.659321
# 3541  138541     0.209454       0.090838   0.010214         1.436775
# 3542  138542     0.182523            NaN        NaN              NaN
#
#       twoMMRstrengthnear  EMcrossfar  EMfracstdfar  EPstdfar  MMRstrengthfar  \
# 0               0.010371    0.300893      0.085965  0.011956        0.086689
# 1               0.013957    0.403777      0.005775  0.000461        0.156924
# 2               0.088234    0.720557      0.016427  0.008207        0.000000
# 3               0.000000    0.235460      0.003955  0.000146        0.013127
# 4                    NaN    0.034058           NaN       NaN             NaN
# ...                  ...         ...           ...       ...             ...
# 3538            0.024447    0.664222      0.031330  0.003745        0.000000
# 3539            0.000000    0.272822      0.002159  0.000486        0.016379
# 3540            0.032653    0.366664      0.067070  0.020456        0.005420
# 3541            0.037776    0.395073      0.102280  0.038515        0.039390
# 3542                 NaN    0.430482           NaN       NaN             NaN
#
#       twoMMRstrengthfar  EMcrossouter  EMfracstdouter  EPstdouter  \
# 0              0.000000      0.589043        0.039301    0.011898
# 1              0.000000      0.671403        0.030466    0.010790
# 2              0.000000      0.936762        0.013904    0.009609
# 3              0.005636      0.503164        0.001251    0.001135
# 4                   NaN      0.059346             NaN         NaN
# ...                 ...           ...             ...         ...
# 3538           0.000000      0.801058        0.003991    0.000199
# 3539           0.003788      0.592730        0.010021    0.007186
# 3540           0.000000      0.546790        0.006147    0.003059
# 3541           0.000000      0.687277        0.066201    0.055396
# 3542                NaN      0.691577             NaN         NaN
#
#       MMRstrengthouter  twoMMRstrengthouter      MEGNO  MEGNOstd  \
# 0             1.283409                  0.0   1.942393  0.032212
# 1             0.000000                  0.0  22.918673  7.372319
# 2             0.000000                  0.0  11.884854  3.404385
# 3             0.000000                  0.0   2.000019  0.001839
# 4                  NaN                  NaN        NaN       NaN
# ...                ...                  ...        ...       ...
# 3538          0.000000                  0.0   1.998822  0.003453
# 3539          0.171046                  0.0   2.487767  0.188649
# 3540          0.074479                  0.0   7.134970  1.931917
# 3541          0.000000                  0.0   2.117164  0.088393
# 3542               NaN                  NaN        NaN       NaN
#
#       prelimStable  Stable
# 0             True   False
# 1             True   False
# 2             True   False
# 3             True    True
# 4            False   False
# ...            ...     ...
# 3538          True   False
# 3539          True   False
# 3540          True   False
# 3541          True   False
# 3542         False   False
#
# [133543 rows x 20 columns]

# %%
new.to_csv('fullFeature2MMRsPlusOuter.csv')
