# %%
import rebound
import numpy as np
import pandas as pd
#from subprocess import call
#import os
import sys
#import warnings
#warnings.filterwarnings('ignore') # to suppress warnings about REBOUND versions that I've already tested
from collections import OrderedDict
#sys.path.append(os.path.join(sys.path[0], '..'))
#from training_data_functions import gen_training_data
#from feature_functions import features
#from additional_feature_functions import additional_features

# %%
#do not know what each initial condition is as of now
col = ['p0m','p0x','p0y','p0z','p0vx','p0vy','p0vz','p1m','p1x','p1y','p1z','p1vx','p1vy','p1vz','p2m','p2x','p2y','p2z','p2vx','p2vy','p2vz','p3m','p3x','p3y','p3z','p3vx','p3vy','p3vz']

# %%
len(col)
# Out:
# 28

# %%
path = 'SPOCKalt'

# %%
#combines labels and initial conditions, as well as gives columns
#/home/ethadhani/SPOCKalt/csvs/random/labels.csv
InitialRandLabels = pd.read_csv("csvs/random/labels.csv", index_col = 0)
rawInitialRand = pd.read_csv("csvs/random/initial_conditions.csv",header=None)
rawInitialRand.columns = col
InitialDataRand = pd.DataFrame.join(InitialRandLabels.loc[:,'runstring'],rawInitialRand) # InitialLabels.loc[:,['instability_time','shadow_instability_time','Stable']])
InitialDataRand = pd.DataFrame.join(InitialDataRand, InitialRandLabels.loc[:,['instability_time','shadow_instability_time','Stable']])

# %%
InitialResLabels = pd.read_csv("csvs/resonant/labels.csv", index_col = 0)
rawInitialRes = pd.read_csv("csvs/resonant/initial_conditions.csv",header=None)
rawInitialRes.columns = col
InitialDataRes = pd.DataFrame.join(InitialResLabels.loc[:,'runstring'],rawInitialRes) # InitialLabels.loc[:,['instability_time','shadow_instability_time','Stable']])
InitialDataRes = pd.DataFrame.join(InitialDataRes, InitialResLabels.loc[:,['instability_time','shadow_instability_time','Stable']])

# %%
InitialDataRes
# Out:
#           runstring       p0m       p0x       p0y           p0z      p0vx  \
# 0       0000000.bin  0.999996  0.000007 -0.000018  1.269113e-07  0.000059
# 1       0000001.bin  1.000000 -0.000020  0.000003 -3.832419e-07 -0.000015
# 2       0000002.bin  1.000000  0.000057 -0.000215 -1.197840e-06  0.000394
# 3       0000003.bin  0.999953  0.000071  0.000045  2.256372e-06 -0.000199
# 4       0000004.bin  0.999996 -0.000063  0.000013  1.256863e-06 -0.000045
# ...             ...       ...       ...       ...           ...       ...
# 113538  9045377.bin  0.999926 -0.000085  0.000010 -1.106312e-06 -0.000199
# 113539  9045378.bin  0.999999 -0.000001 -0.000020  1.065355e-06  0.000080
# 113540  9045380.bin  0.999907 -0.000104 -0.000041  5.086933e-08  0.000238
# 113541  9045382.bin  0.999980 -0.000010 -0.000041 -2.574202e-06  0.000229
# 113542  9045383.bin  0.999991 -0.000008  0.000025  1.473082e-06 -0.000087
#
#             p0vy          p0vz           p1m       p1x  ...           p3m  \
# 0       0.000031 -7.653712e-08  3.984920e-06 -0.982960  ...  2.531702e-07
# 1      -0.000092  2.664138e-06  2.065557e-07  0.845257  ...  6.830431e-07
# 2       0.000225  1.018178e-06  1.797281e-07  0.899352  ...  9.648477e-05
# 3       0.000297 -1.334874e-06  4.704418e-05 -0.819392  ...  1.615758e-05
# 4      -0.000265 -3.323176e-06  3.514145e-06  0.865534  ...  4.655600e-05
# ...          ...           ...           ...       ...  ...           ...
# 113538 -0.000485 -1.129686e-06  7.421231e-05  0.833564  ...  1.797223e-05
# 113539  0.000008  5.281562e-07  7.304962e-07 -0.408337  ...  7.962694e-06
# 113540 -0.000572 -9.592409e-06  9.256666e-05  1.000964  ...  3.800687e-06
# 113541 -0.000051 -3.800051e-06  1.973852e-05  0.794873  ...  1.439586e-07
# 113542 -0.000044 -7.731798e-07  9.046494e-06  0.489348  ...  1.103757e-05
#
#              p3x       p3y       p3z      p3vx      p3vy      p3vz  \
# 0      -1.288724  0.962201 -0.018973 -3.077432 -3.851732 -0.164377
# 1      -1.327142  0.550229 -0.009861 -1.680953 -4.761961 -0.052477
# 2      -0.208863  2.258035  0.009349 -4.143923 -0.430091 -0.016918
# 3      -2.003066 -0.132781 -0.004192  0.293880 -4.423427  0.115038
# 4       1.292557 -0.324317 -0.026652  1.326032  5.277415  0.076018
# ...          ...       ...       ...       ...       ...       ...
# 113538  1.326230  1.220321 -0.000086 -3.298997  3.317568  0.004904
# 113539  1.364057  0.821248 -0.042233 -2.573925  4.260193 -0.105326
# 113540  1.452589  0.534914  0.003231 -1.743623  4.737535  0.001599
# 113541  0.608904 -1.585241 -0.003246  4.409912  1.910862  0.012007
# 113542  0.804495 -1.405040 -0.122980  3.475401  3.633719  0.078112
#
#         instability_time  shadow_instability_time  Stable
# 0           1.545872e+06             3.063700e+06   False
# 1           9.990000e+08             9.990000e+08    True
# 2           9.990000e+08             9.990000e+08    True
# 3           2.287671e+06             8.392234e+06   False
# 4           9.668931e+05             3.380350e+05   False
# ...                  ...                      ...     ...
# 113538      6.990387e+05             8.267916e+05   False
# 113539      3.075749e+08             6.576003e+08   False
# 113540      1.193822e+07             3.363291e+07   False
# 113541      2.064407e+08             4.316851e+07   False
# 113542      2.266066e+04             2.228425e+04   False
#
# [113543 rows x 32 columns]

# %%
InitialData = pd.concat([InitialDataRand, InitialDataRes])

# %%
InitialData[["EMcrossnear", "EMfracstdnear","EPstdnear","MMRstrengthnear", "twoMMRstrengthnear", "EMcrossfar","EMfracstdfar","EPstdfar","MMRstrengthfar","twoMMRstrengthfar","MEGNO", "MEGNOstd", "prelimStable"]] = None

# %%
InitialData
# Out:
#           runstring       p0m       p0x           p0y           p0z      p0vx  \
# 0       0000000.bin  1.000000  0.000022 -2.831350e-05 -3.597028e-07  0.000185
# 1       0000001.bin  1.000000 -0.000011  4.130650e-05 -6.279490e-07 -0.000194
# 2       0000002.bin  1.000000  0.000108  9.138333e-05  2.407310e-07 -0.000512
# 3       0000003.bin  1.000000  0.000002 -3.770679e-06 -1.093975e-07  0.000019
# 4       0000004.bin  1.000000 -0.000001 -3.992887e-07 -3.545834e-08  0.000002
# ...             ...       ...       ...           ...           ...       ...
# 113538  9045377.bin  0.999926 -0.000085  9.842459e-06 -1.106312e-06 -0.000199
# 113539  9045378.bin  0.999999 -0.000001 -2.024681e-05  1.065355e-06  0.000080
# 113540  9045380.bin  0.999907 -0.000104 -4.131313e-05  5.086933e-08  0.000238
# 113541  9045382.bin  0.999980 -0.000010 -4.062228e-05 -2.574202e-06  0.000229
# 113542  9045383.bin  0.999991 -0.000008  2.474930e-05  1.473082e-06 -0.000087
#
#             p0vy          p0vz           p1m       p1x  ...  MMRstrengthnear  \
# 0       0.000118 -2.108359e-06  3.414016e-05 -0.065840  ...             None
# 1      -0.000005 -4.520213e-06  2.529838e-07 -0.907953  ...             None
# 2       0.000623 -2.402166e-06  7.380789e-05 -0.984675  ...             None
# 3       0.000005 -5.933343e-07  5.174804e-07  0.944414  ...             None
# 4      -0.000008 -6.548437e-08  5.106746e-07 -0.739837  ...             None
# ...          ...           ...           ...       ...  ...              ...
# 113538 -0.000485 -1.129686e-06  7.421231e-05  0.833564  ...             None
# 113539  0.000008  5.281562e-07  7.304962e-07 -0.408337  ...             None
# 113540 -0.000572 -9.592409e-06  9.256666e-05  1.000964  ...             None
# 113541 -0.000051 -3.800051e-06  1.973852e-05  0.794873  ...             None
# 113542 -0.000044 -7.731798e-07  9.046494e-06  0.489348  ...             None
#
#         twoMMRstrengthnear  EMcrossfar  EMfracstdfar  EPstdfar  \
# 0                     None        None          None      None
# 1                     None        None          None      None
# 2                     None        None          None      None
# 3                     None        None          None      None
# 4                     None        None          None      None
# ...                    ...         ...           ...       ...
# 113538                None        None          None      None
# 113539                None        None          None      None
# 113540                None        None          None      None
# 113541                None        None          None      None
# 113542                None        None          None      None
#
#         MMRstrengthfar  twoMMRstrengthfar  MEGNO  MEGNOstd  prelimStable
# 0                 None               None   None      None          None
# 1                 None               None   None      None          None
# 2                 None               None   None      None          None
# 3                 None               None   None      None          None
# 4                 None               None   None      None          None
# ...                ...                ...    ...       ...           ...
# 113538            None               None   None      None          None
# 113539            None               None   None      None          None
# 113540            None               None   None      None          None
# 113541            None               None   None      None          None
# 113542            None               None   None      None          None
#
# [138543 rows x 45 columns]

# %%
sys.path.insert(1, 'Intigration')
#Intigration/simsetup.py
import simsetup

# %%
sim = simsetup.get_sim(40000,InitialData)

# %%
import spock
from spock import FeatureClassifier
model = FeatureClassifier()
# Out:
# [23:27:04] WARNING: /croot/xgboost-split_1675457761144/work/src/learner.cc:888: Found JSON model saved before XGBoost 1.6, please save the model using current version again. The support for old JSON model will be discontinued in XGBoost 2.3.

# %%
# %%time
model.predict_stable(sim)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed eval>:1
#
# File /home/miniconda3/envs/cneely/lib/python3.9/site-packages/spock/featureclassifier.py:35, in FeatureClassifier.predict_stable(self, sim, n_jobs)
#      20 def predict_stable(self, sim, n_jobs=-1):
#      21     """
#      22     Predict whether passed simulation will be stable over 10^9 orbits of the innermost planet.
#      23
#    (...)
#      33
#      34     """
# ---> 35     res = self.generate_features(sim, n_jobs=n_jobs)
#      37     try: # separate the feature dictionaries from the bool for whether it was stable over short integration
#      38         stable = np.array([r[1] for r in res])
#
# File /home/miniconda3/envs/cneely/lib/python3.9/site-packages/spock/featureclassifier.py:101, in FeatureClassifier.generate_features(self, sim, n_jobs)
#      98     return triofeatures, stable
#     100 if len(args) == 1: # single sim
# --> 101     res = run(args[0])    # stable will be 0 if an orbit is hyperbolic
#     102 else:
#     103     if n_jobs == -1:
#
# File /home/miniconda3/envs/cneely/lib/python3.9/site-packages/spock/featureclassifier.py:97, in FeatureClassifier.generate_features.<locals>.run(params)
#      95 def run(params):
#      96     sim, featureargs = params
# ---> 97     triofeatures, stable = features(sim, featureargs)
#      98     return triofeatures, stable
#
# File /home/miniconda3/envs/cneely/lib/python3.9/site-packages/spock/feature_functions.py:155, in features(sim, args)
#     152     features['MEGNOstd'] = np.nan
#     153     triofeatures.append(features)
# --> 155 triotseries, stable = get_tseries(sim, args)
#     156 if stable == False:
#     157     return triofeatures, stable
#
# File /home/miniconda3/envs/cneely/lib/python3.9/site-packages/spock/feature_functions.py:130, in get_tseries(sim, args)
#     128         pairs = triopairs[tr]
#     129         tseries = triotseries[tr]
# --> 130         populate_trio(sim, trio, pairs, tseries, i)
#     132 stable = True
#     133 return triotseries, stable
#
# File /home/miniconda3/envs/cneely/lib/python3.9/site-packages/spock/feature_functions.py:96, in populate_trio(sim, trio, pairs, tseries, i)
#      93     tseries[i,Ns*q+2] = np.sqrt((m1*e1x + m2*e2x)**2 + (m1*e1y + m2*e2y)**2)/(m1+m2)
#      94     j, k, tseries[i,Ns*q+3] = find_strongest_MMR(sim, i1, i2)
# ---> 96 tseries[i,7] = sim.calculate_megno()
#
# AttributeError: 'Simulation' object has no attribute 'calculate_megno'

# %%
sim.save_to_file("snapshot.bin")

# %%
from Intigration import *

# %%
from featureKlassifier import *

# %%
# %%time
simToData(sim)
# Out:
# [OrderedDict([('EMcrossnear', 0.5373555409980062), ('EMfracstdnear', 0.030447490093998723), ('EPstdnear', 0.0076724613594876), ('MMRstrengthnear', 0.0), ('twoMMRstrengthnear', 0.0), ('EMcrossfar', 0.5681362177606247), ('EMfracstdfar', 0.005632983968766378), ('EPstdfar', 0.0007630912892021247), ('MMRstrengthfar', 0.0), ('twoMMRstrengthfar', 0.0), ('MEGNO', 2.005149779559531), ('MEGNOstd', 0.00041800698881840287)]), True]
# CPU times: user 547 ms, sys: 0 ns, total: 547 ms
# Wall time: 546 ms
